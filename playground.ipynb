# %%
from flask import Flask, request, render_template, jsonify
from bs4 import BeautifulSoup as bs
import requests
from flask_cors import CORS, cross_origin
from urllib.request import urlopen as uo

# %%
product_name = "iphone13"

# %%
required_url = "https://www.amazon.in/s?k="+product_name

# %%
url_client = uo(required_url)
url_client

# %%
html_scrap = url_client.read()
url_client.close()
html_scrap
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>\n<link rel="preconnect" href="https://m.media-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>\n<link rel="preconnect" href="https://completion.amazon.com" crossorigin>\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n\n<!-- sp:end-feature:csm:head-open
# ...

# %%
formatted_html_scrap = bs(html_scrap, "html.parser")
formatted_html_scrap
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# ...

# %%
search_result = formatted_html_scrap.find_all("div", {"class":"sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col s-widget-spacing-small sg-col-12-of-16"})
search_result
# Out:
# [<div class="sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col s-widget-spacing-small sg-col-12-of-16" data-asin="B09G9FPGTN" data-component-type="s-search-result" data-index="2" data-uuid="6fc7f4d9-a1c7-4ab8-be2e-3493218b16d7"><div class="sg-col-inner"><div cel_widget_id="MAIN-SEARCH_RESULTS-2" class="s-widget-container s-spacing-small s-widget-container-height-small celwidget slot=MAIN template=SEARCH_RESULTS widgetId=search-results_1" data-csa-c-item-id="amzn1.asin.1.B09G9FPGTN" data-csa-c-pos="1" data-csa-c-type="item" data-csa-op-log-render=""><span class="a-declarative" data-action="puis-card-container-declarative" data-csa-c-func-deps="aui-da-puis-card-container-declarative" data-csa-c-type="widget" data-render-id="r2fbv3bissxjz721ujqbfeo70wm" data-version-id="v3o2zdxdjaxcix2e3x4m988k53u"><div class="puis-card-container s-card-container s-overflow-hidden aok-relative puis-include-content-margin puis puis-v3o2zdxdjaxcix2e3x4m988k53u s-latency-cf-section
# ...

# %%
product_link = search_result[0].find_all("a")[0]["href"]
product_link
# Out:
# '/Apple-iPhone-13-128GB-Pink/dp/B09G9FPGTN'

# %%
product_url = "https://www.amazon.in"+product_link
url_client = uo(product_url)
url_client

# %%
product_html_scrap = url_client.read()
product_html_scrap
# Out:
# b'\n\n\n  \n  \n  \n  \n\n\n\n\n\n\n\n\n        \n        \n    \n\n\n\n\n\n    \n    \n\n\n\n\n\n\n\n\n\n\n\n\n \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n \n\n\n\n\n\n\n\n\n\n\n\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n    <!doctype html><html class="a-no-js" data-19ax5a9jf="dingo">\n    <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8">\n\n    \n\n\n\n    <link rel="dns-prefetch" href="//images-eu.ssl-images-amazon.com">\n    <link rel="dns-prefetch" href="//images-na.ssl-images-amazon.com">\n\n\n\n    \n\n\n\n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n            \n        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n    \n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n    \n\n\n\n\n\n            \n\n\n            \n\n\n            \n\n        \n\n            \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\n\n\n\n\n\n\n        \n\n\n\n\n\n\n        \n        \n        \n  \n\n\n\n\n\n\n\n\n   
# ...

# %%
formatted_product_scrap = bs(product_html_scrap,"html.parser")
formatted_product_scrap
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo">
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <link href="//images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="//images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <!-- NAVYAAN CSS -->
# <style type="text/css">
# .nav-sprite-v1 .nav-sprite, .nav-sprite-v1 .nav-icon {
#   background-image: url(https://m.media-amazon.com/images/G/31/gno/sprites/nav-sprite-global-1x-reorg-privacy._CB600086755_.png);
#   background-position: 0 1000px;
#   background-repeat: repeat-x;
# }
# .nav-spinner {
#   background-image: url(https://m.media-amazon.com/images/G/31/javascripts/lib/popover/images/snake._CB485935600_.gif);
#   background-position: center center;
#   background-repeat: no-repeat;
# }
# .nav-timeline-icon, .nav-access-image, .nav-timeline-prime-icon {
# ...

# %%
all_reviews = formatted_product_scrap.find_all("div", {"class" : "a-section review aok-relative"})

# %%
len(all_reviews)
# Out:
# 4

# %% [markdown]
# We've got 8 reviews

# %%
names = list()
for values in all_reviews:
    names.append(values.div.div.div.find_all("div", {"class" : "a-profile-content"})[0].text)

# %%
names
# Out:
# ['vaibhav', 'Sarfaraz', 'Pavan', 'Ayesha']

# %% [markdown]
# SUCCESSFULLY SCRAPPED NAMES

# %%
user_rating = list()
for value in all_reviews:
    user_rating.append(value.div.div.i.text)

# %%
user_rating
# Out:
# ['5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars']

# %% [markdown]
# RATING SCRAPPED SUCCESSFULLY

# %%
review_heading = list()
for value in all_reviews:
    review_heading.append(value.div.div.find_all("span")[3].text)

# %%
review_heading
# Out:
# ['So Beautiful, So elegant, just looking like a wow.',
#  'Technological Marvel!',
#  'After usage of 10 days',
#  'Switched from Android to IOS, loved the experience, but..']

# %% [markdown]
# REVIEW HEADINGS SCRAPPED SUCCESSFULLY

# %%
review_date = list()
for value in all_reviews:
    date_str = value.div.div.find_all("span")[4].text
    review_date.append(date_str[21:])

# %%
review_date
# Out:
# ['13 November 2023', '25 December 2023', '21 October 2023', '18 December 2023']

# %% [markdown]
# REVIEW DATE SCRAPPED SUCCESSFULLY

# %%
all_reviews[0].div.div.find_all("span")[7].text
# Out:
# "\nI snagged the iPhone 13 during the Great Indian Festival for an unbeatable price of 45,000, and let me tell you, it's been a game-changer in every way!Screen: The display is absolutely stunning – crisp, vibrant, and the colors pop like never before. Watching videos or scrolling through photos is a treat for the eyes. No complaints here!Hanging: Zero issues with hanging or lagging. This phone handles multitasking like a champ. Switching between apps is smooth, and I haven't experienced any frustrating delays.Battery: The battery life is surprisingly impressive. I can go a full day with normal usage, and it still has juice left in the tank. No more anxiously searching for a charger midday – a definite win!Comfort: The sleek design makes it a pleasure to hold, and the phone is just the right weight. It feels premium and comfortable in my hand, making it a joy to use for extended periods.Image Quality: The camera on the iPhone 13 is a true standout. The photos are sharp, and the night
# ...

# %%
required_text = list()
for value in all_reviews:
    required_text.append(str(value.div.div.find_all("span")[7])[6:-7])

# %% [markdown]
# del(required_text[3])

# %%
review = required_text[0].replace("<br>","\n")
review = review.replace("<br/>","\n")
review = review.replace("</br>","")
print(review)
# Out:
# class="a-size-base review-text" data-hook="review-body"><div class="a-expander-collapsed-height a-row a-expander-container a-expander-partial-collapse-container" data-a-expander-collapsed-height="300" data-a-expander-name="review_text_read_more" style="max-height:300px"><div aria-expanded="false" class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content" data-hook="review-collapsed">
# <span>I snagged the iPhone 13 during the Great Indian Festival for an unbeatable price of 45,000, and let me tell you, it's been a game-changer in every way!
#
# Screen: The display is absolutely stunning – crisp, vibrant, and the colors pop like never before. Watching videos or scrolling through photos is a treat for the eyes. No complaints here!
#
# Hanging: Zero issues with hanging or lagging. This phone handles multitasking like a champ. Switching between apps is smooth, and I haven't experienced any frustrating delays.
#
# ...

# %%
detailed_review = list()
for review in all_reviews:
    detailed_review.append(review.div.div.find_all("span")[7].text)

# %%
len(detailed_review)
# Out:
# 4

# %%
detailed_review[0]
# Out:
# "\nI snagged the iPhone 13 during the Great Indian Festival for an unbeatable price of 45,000, and let me tell you, it's been a game-changer in every way!Screen: The display is absolutely stunning – crisp, vibrant, and the colors pop like never before. Watching videos or scrolling through photos is a treat for the eyes. No complaints here!Hanging: Zero issues with hanging or lagging. This phone handles multitasking like a champ. Switching between apps is smooth, and I haven't experienced any frustrating delays.Battery: The battery life is surprisingly impressive. I can go a full day with normal usage, and it still has juice left in the tank. No more anxiously searching for a charger midday – a definite win!Comfort: The sleek design makes it a pleasure to hold, and the phone is just the right weight. It feels premium and comfortable in my hand, making it a joy to use for extended periods.Image Quality: The camera on the iPhone 13 is a true standout. The photos are sharp, and the night
# ...

# %% [markdown]
# DETAILED REVIEW SCRAPPED

# %% [markdown]
# AMAZON REVIEW SCRAPPER PROTOTYPE COMPLETE
